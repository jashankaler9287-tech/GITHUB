# %%
a = 20
b = 10
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(a // b)
print(a ** b)
print(a > b)
print(a == b)
# Out:
# 30
# 10
# 200
# 2.0
# 0
# 2
# 10240000000000
# True
# False
