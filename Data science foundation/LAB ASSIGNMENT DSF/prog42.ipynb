# %%
maths = 80
python = 90
english = 75
total = maths + python + english
average = total / 3
print("Total marks:", total)
print("Average marks:", average)
print("Total greater than 200:", total > 200)
print("Python marks equal to 90:", python == 90)
# Out:
# Total marks: 245
# Average marks: 81.66666666666667
# Total greater than 200: True
# Python marks equal to 90: True
